# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
name=None
i=0
for nam in df.columns:
    name=df.columns[i].lower()
    df=df.rename(columns={df.columns[i]:name})
    i=i+1


df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Change the Index to be the Line Names

# %%
df = df.set_index(['linename'])
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
df['linename'] = df.index

df.index = range(len(df)) 
df.head()
# Out:
#     c/a  unit       scp station division        date      time     desc  \
# 0  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00  REGULAR
# 1  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00  REGULAR
# 2  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00  REGULAR
# 3  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00  REGULAR
# 4  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00  REGULAR
#
#    entries  \
# 0  6736067
# 1  6736087
# 2  6736105
# 3  6736180
# 4  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#   linename
# 0  NQR456W
# 1  NQR456W
# 2  NQR456W
# 3  NQR456W
# 4  NQR456W

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# Your code here
#numline={}
#numline['station']=df.station.unique()
#numline
df['Num_Lines'] = df.linename.map(lambda x: len(x))
df.head()
# Out:
#     c/a  unit       scp station division        date      time     desc  \
# 0  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00  REGULAR
# 1  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00  REGULAR
# 2  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00  REGULAR
# 3  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00  REGULAR
# 4  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00  REGULAR
#
#    entries  \
# 0  6736067
# 1  6736087
# 2  6736105
# 3  6736180
# 4  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#   linename  Num_Lines
# 0  NQR456W          7
# 1  NQR456W          7
# 2  NQR456W          7
# ...

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.strip() 
    #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'division', 'date', 'time', 'desc',
#        'entries', 'exits', 'linename', 'Num_Lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
df.date = pd.to_datetime(df.date)

df['Dayofweek'] = df.date.dt.dayofweek
df.Dayofweek
grouped = df.groupby('Dayofweek').sum()
grouped
grouped.plot(kind='bar')
#grouped = df.groupby('station').sum()
#grouped

# %%
# groupes =  df.groupby('Dayofweek').sum()

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here
#df['week_end']=[]
test =[]

for day in df.Dayofweek:
    if day == 0 :
        test.append(1)
    elif day == 6:
            test.append(1)
    else :
        test.append(0)

len(df.Dayofweek)

df['weekend']=test

df.groupby('weekend').mean()
groups=df.groupby('weekend').mean()

my_plot=groups.entries.plot (kind='barh')
#plt.ylabel('')
#my_plot.set_ylables(['weekend','weekday'])

#df.weekend.unique()

#df.weekend.plot(kind='bar')
#groups.plot(x={0,1}, y=groups["entries"].median(), kind="bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-f6ca49f987da> in <module>()
#      19
#      20 my_plot=groups.entries.plot (kind='barh')
# ---> 21 plt.ylabel('')
#      22 #my_plot.set_ylables(['weekend','weekday'])
#      23
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here

df.drop(['c/a','desc'], axis=1)
df.head()
# Out:
#     c/a  unit       scp station division       date      time     desc  \
# 0  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00  REGULAR
# 1  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00  REGULAR
# 2  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00  REGULAR
# 3  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00  REGULAR
# 4  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00  REGULAR
#
#    entries    exits linename  Num_Lines  Dayofweek  weekend
# 0  6736067  2283184  NQR456W          7          5        0
# 1  6736087  2283188  NQR456W          7          5        0
# 2  6736105  2283229  NQR456W          7          5        0
# 3  6736180  2283314  NQR456W          7          5        0
# 4  6736349  2283384  NQR456W          7          5        0
